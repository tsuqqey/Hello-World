# %% [markdown]
# <a href="https://colab.research.google.com/github/tsuqqey/Hello-World/blob/main/kiva.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#環境確認
import pandas as pd
import numpy as np
# !python3 --version
import matplotlib

#データの読み込み
train_df = pd.read_csv("/content/train.csv")
test_df = pd.read_csv("/content/test.csv")
submit_df = pd.read_csv("/content/sample_submission.csv")
# Out:
# Python 3.7.12

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split


#df_train_all,df_test_all=train_test_split(train_df, test_size=20000, random_state=0)




# 学習データCSVファイル読み込み
df_train_all = pd.read_csv('/content/train.csv')
# 融資額を目的変数（ターゲット）にする
y_train = df_train_all[u'LOAN_AMOUNT'].values.tolist()

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['ORIGINAL_LANGUAGE'])
#オリジナル言語を整数に変換
df_train_all['ORIGINAL_LANGUAGE'] = le.transform(df_train_all['ORIGINAL_LANGUAGE'])
                                                              
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['ACTIVITY_NAME'])
#オリジナル言語を整数に変換
df_train_all['ACTIVITY_NAME'] = le.transform(df_train_all['ACTIVITY_NAME'])

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['SECTOR_NAME'])
#オリジナル言語を整数に変換
df_train_all['SECTOR_NAME'] = le.transform(df_train_all['SECTOR_NAME'])     

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['COUNTRY_CODE'])
#オリジナル言語を整数に変換
df_train_all['COUNTRY_CODE'] = le.transform(df_train_all['COUNTRY_CODE'])   

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['CURRENCY_POLICY'])
#オリジナル言語を整数に変換
df_train_all['CURRENCY_POLICY'] = le.transform(df_train_all['CURRENCY_POLICY'])   
       
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['REPAYMENT_INTERVAL'])
#オリジナル言語を整数に変換
df_train_all['REPAYMENT_INTERVAL'] = le.transform(df_train_all['REPAYMENT_INTERVAL'])  
       
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['DISTRIBUTION_MODEL'])
#オリジナル言語を整数に変換
df_train_all['DISTRIBUTION_MODEL'] = le.transform(df_train_all['DISTRIBUTION_MODEL'])  
         
    
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['LOAN_USE'])
#オリジナル言語を整数に変換
df_train_all['LOAN_USE'] = le.transform(df_train_all['LOAN_USE'])  
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['COUNTRY_NAME'])
#オリジナル言語を整数に変換
df_train_all['COUNTRY_NAME'] = le.transform(df_train_all['COUNTRY_NAME'])  

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_train_all['CURRENCY'])
#オリジナル言語を整数に変換
df_train_all['CURRENCY'] = le.transform(df_train_all['CURRENCY'])  
    
    
    
    
# train_data
# 不要な列を切り落として説明変数にする
data_train = df_train_all.drop(
    ['LOAN_ID','LOAN_AMOUNT', 'DESCRIPTION', 'DESCRIPTION_TRANSLATED','LOAN_USE',
        'IMAGE_ID', 'TOWN_NAME',
       'CURRENCY_EXCHANGE_COVERAGE_RATE','CURRENCY', 'TAGS'
      ], axis=1)
x_train = data_train.values.tolist()


# テスト用データCSV読み込み
df_test_all = pd.read_csv('/content/test.csv')
# 融資額を目的変数（ターゲット）にする
#y_test = df_test_all[u'LOAN_AMOUNT'].values.tolist()

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['ORIGINAL_LANGUAGE'])
#オリジナル言語を整数に変換
df_test_all['ORIGINAL_LANGUAGE'] = le.transform(df_test_all['ORIGINAL_LANGUAGE'])
                                                              
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['ACTIVITY_NAME'])
#オリジナル言語を整数に変換
df_test_all['ACTIVITY_NAME'] = le.transform(df_test_all['ACTIVITY_NAME'])

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['SECTOR_NAME'])
#オリジナル言語を整数に変換
df_test_all['SECTOR_NAME'] = le.transform(df_test_all['SECTOR_NAME'])     

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['COUNTRY_CODE'])
#オリジナル言語を整数に変換
df_test_all['COUNTRY_CODE'] = le.transform(df_test_all['COUNTRY_CODE'])   

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['CURRENCY_POLICY'])
#オリジナル言語を整数に変換
df_test_all['CURRENCY_POLICY'] = le.transform(df_test_all['CURRENCY_POLICY']) 

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['REPAYMENT_INTERVAL'])
#オリジナル言語を整数に変換
df_test_all['REPAYMENT_INTERVAL'] = le.transform(df_test_all['REPAYMENT_INTERVAL'])  
       
le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['DISTRIBUTION_MODEL'])
#オリジナル言語を整数に変換
df_test_all['DISTRIBUTION_MODEL'] = le.transform(df_test_all['DISTRIBUTION_MODEL']) 

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['LOAN_USE'])
#オリジナル言語を整数に変換
df_test_all['LOAN_USE'] = le.transform(df_test_all['LOAN_USE'])  

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['COUNTRY_NAME'])
#オリジナル言語を整数に変換
df_test_all['COUNTRY_NAME'] = le.transform(df_test_all['COUNTRY_NAME'])  

le = LabelEncoder()
#オリジナル言語を覚えさせる
le = le.fit(df_test_all['CURRENCY'])
#オリジナル言語を整数に変換
df_test_all['CURRENCY'] = le.transform(df_test_all['CURRENCY'])  

#   test_data
# 不要な列を切り落として説明変数にする
data_test = df_test_all.drop(
    ['LOAN_ID','DESCRIPTION', 'DESCRIPTION_TRANSLATED','LOAN_USE',
        'IMAGE_ID',  'TOWN_NAME',
      'CURRENCY_EXCHANGE_COVERAGE_RATE', 'CURRENCY', 'TAGS'
      ], axis=1)
x_test = data_test.values.tolist()
# ランダムフォレスト回帰オブジェクト生成
rfr = RandomForestRegressor(n_estimators=100)
# 学習の実行
rfr.fit(x_train, y_train)
# テストデータで予測実行
predict_y = rfr.predict(x_test)


'''
# R2決定係数で評価
r2_score = r2_score(y_test, predict_y)
print(r2_score)
# 特徴量の重要度を取得
feature = rfr.feature_importances_
# 特徴量の名前ラベルを取得
label = data_train.columns[0:]
# 特徴量の重要度順（降順）に並べて表示
indices = np.argsort(feature)[::-1]
for i in range(len(feature)):
    print(str(i + 1) + "   " +
          str(label[indices[i]]) + "   " + str(feature[indices[i]]))
    
# 融資額の実績と予測値の比較グラフ
plt.subplot(121, facecolor='white')
plt.title('loan_amount diff')
plt_label = [i for i in range(1, 32)]
# 特徴量の重要度の棒グラフ
plt.subplot(122, facecolor='white')
plt.title('fearture value weight')
plt.bar(
    range(
        len(feature)),
    feature[indices],
    color='blue',
    align='center')
plt.xticks(range(len(feature)), label[indices], rotation=45)
plt.xlim([-1, len(feature)])
plt.tight_layout()
# グラフの表示
plt.show()
'''
# Out:
# '\n# R2決定係数で評価\nr2_score = r2_score(y_test, predict_y)\nprint(r2_score)\n# 特徴量の重要度を取得\nfeature = rfr.feature_importances_\n# 特徴量の名前ラベルを取得\nlabel = data_train.columns[0:]\n# 特徴量の重要度順（降順）に並べて表示\nindices = np.argsort(feature)[::-1]\nfor i in range(len(feature)):\n    print(str(i + 1) + "   " +\n          str(label[indices[i]]) + "   " + str(feature[indices[i]]))\n    \n# 融資額の実績と予測値の比較グラフ\nplt.subplot(121, facecolor=\'white\')\nplt.title(\'loan_amount diff\')\nplt_label = [i for i in range(1, 32)]\n# 特徴量の重要度の棒グラフ\nplt.subplot(122, facecolor=\'white\')\nplt.title(\'fearture value weight\')\nplt.bar(\n    range(\n        len(feature)),\n    feature[indices],\n    color=\'blue\',\n    align=\'center\')\nplt.xticks(range(len(feature)), label[indices], rotation=45)\nplt.xlim([-1, len(feature)])\nplt.tight_layout()\n# グラフの表示\nplt.show()\n'

# %%
train_df.head()
# Out:
#    LOAN_ID ORIGINAL_LANGUAGE  ... REPAYMENT_INTERVAL DISTRIBUTION_MODEL
# 0  1733169           English  ...            monthly      field_partner
# 1  1546998           English  ...            monthly      field_partner
# 2  1808517           Spanish  ...             bullet      field_partner
# 3  1452940           English  ...            monthly      field_partner
# 4  1778420           English  ...             bullet      field_partner
#
# [5 rows x 18 columns]

# %%
print(df_test_all.head)
print(df_train_all.head)
# Out:
# <bound method NDFrame.head of        LOAN_ID  ORIGINAL_LANGUAGE  ... REPAYMENT_INTERVAL DISTRIBUTION_MODEL
# 67894  1618303                  0  ...                  2                  1
# 16822  1797129                  0  ...                  2                  1
# 57068  1757855                  0  ...                  2                  1
# 69098  1742516                  4  ...                  2                  1
# 78066  1678917                  1  ...                  0                  1
# ...        ...                ...  ...                ...                ...
# 3024   1879517                  0  ...                  2                  1
# 61716  1469896                  0  ...                  2                  1
# 53520  1570946                  4  ...                  2                  1
# 51004  1696743                  0  ...                  2                  1
# 32922  1886170                  0  ...                  2                  1
#
# ...

# %%
# R2決定係数で評価
r2_score = r2_score(y_test, predict_y)
print(r2_score)
# 特徴量の重要度を取得
feature = rfr.feature_importances_
# 特徴量の名前ラベルを取得
label = data_train.columns[0:]
# 特徴量の重要度順（降順）に並べて表示
indices = np.argsort(feature)[::-1]
for i in range(len(feature)):
    print(str(i + 1) + "   " +
          str(label[indices[i]]) + "   " + str(feature[indices[i]]))
    
# 融資額の実績と予測値の比較グラフ
plt.subplot(121, facecolor='white')
plt.title('loan_amount diff')
plt_label = [i for i in range(1, 32)]
# 特徴量の重要度の棒グラフ
plt.subplot(122, facecolor='white')
plt.title('fearture value weight')
plt.bar(
    range(
        len(feature)),
    feature[indices],
    color='blue',
    align='center')
plt.xticks(range(len(feature)), label[indices], rotation=45)
plt.xlim([-1, len(feature)])
plt.tight_layout()
# グラフの表示
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-144cda3785da> in <module>()
#       2
#       3 # R2決定係数で評価
# ----> 4 r2_score = r2_score(y_test, predict_y)
#       5 print(r2_score)
#       6 # 特徴量の重要度を取得
#
# NameError: name 'y_test' is not defined

# %%
#説明変数の作成
test_X = pd.get_dummies(df_test_all['ACTIVITY_NAME'], drop_first=True)
#テスト結果の出力
#test_predicted = model.predict(test_X)
submit_df['LOAN_AMOUNT']=predict_y
submit_df.to_csv('/content/submission.csv',index=False)
